# %%
import numpy as np
a = np.random.randint(10,size= 10)
a
# Out:
# array([5, 0, 1, 1, 8, 7, 4, 9, 0, 3])

# %%
a[0]
# Out:
# 5

# %%
a[-1]
# Out:
# 3

# %%
a[0] = 100

# %%
a
# Out:
# array([100,   0,   1,   1,   8,   7,   4,   9,   0,   3])

# %%
m = np.random.randint(10, size= (3,5))

# %%
m
# Out:
# array([[9, 2, 7, 4, 3],
#        [4, 3, 3, 4, 3],
#        [9, 4, 6, 5, 5]])

# %%
m[0,0]
# Out:
# 9

# %%
m[1,0]
# Out:
# 4

# %%
m[1,4]
# Out:
# 3

# %%
m[1,4] = 99

# %%
m
# Out:
# array([[ 9,  2,  7,  4,  3],
#        [ 4,  3,  3,  4, 99],
#        [ 9,  4,  6,  5,  5]])

# %%
m[1,4] = 2.2

# %%
m
# Out:
# array([[9, 2, 7, 4, 3],
#        [4, 3, 3, 4, 2],
#        [9, 4, 6, 5, 5]])
